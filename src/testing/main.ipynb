# %%
import torch
import torch.nn as nn
from check import setup_torch

device = setup_torch()
# Out:
# ✅ Using CUDA globally
# GPU: NVIDIA GeForce RTX 4090

# %%
from helper.data_retrev import load_mels_with_labels_tuples

mels = load_mels_with_labels_tuples()


print(len(mels))        # number of songs
  # (n_mels, T_min)
# Out:
# processing segah--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_1--12_Taqasim_Iraq.mp3
# labeling as segah
# processing rast--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_2--04_Taqsim_Rasd_(Baidaphon).mp3
# labeling as rast
# processing kurd--Taqasim_Kurdlihejazkar_Qasabji.mp3.mp3
# labeling as kurd
# processing hijazkar--Mohammad_al-Qasabji--Various--Taqsim_Hijaz_Kar.mp3
# labeling as hijazkar
# processing bayat--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_2--13_Taqsim_Shuri_(Colombia).mp3
# labeling as bayat
# processing nahawand--George_Abyad--Taksims_Oud--nahawand--(8M_32S).mp3
# labeling as nahawand
# Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# processing rast--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_1--02_Qadd_Al-Rasd_Bashraf_(Odeon).mp3
# labeling as rast
# processing segah--Riyadh_Al-Sunbati--Maqamat--Taqaseem_Sika.mp3
# labeling as segah
# processing kurd--Ali_Jihad_Racy--Simon_Shaheen_‎–_Taqasim__Improvisation_In_Arabic_Music--01_Maqam_Kurd.m4a.mp3
# labeling as kurd
# processing segah--George_Abyad--Taksims_Oud--Houzam_(6M_38S).mp3
# labeling as segah
# Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# processing nahawand--Jamil_Bashir--unknown_album--Samai_nahawand--Jamil_Bashir.mp3
# labeling as nahawand
# processing nahawand--Ehsan_Emam--Bein_Al-Nahrain--Bedayat_Hob_(Nahawand).mp3
# labeling as nahawand
# processing segah--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_2--03_Taqsim_Sikah_(Odeon).mp3
# labeling as segah
# processing segah--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_2--16_Taqsim_Sikah_(Colombia).mp3
# labeling as segah
# processing segah--Munir_Bashir-Art_of_the_Ud-04_Taqsim_en_Maqam__Awj.mp3
# labeling as segah
# [src/libmpg123/id3.c:process_comment():587] error: No comment text / valid description?
# processing nahawand--Taqasim_nahawand--Qasabji.mp3.mp3
# labeling as nahawand
# processing nahawand--Omar_Naqichbendi--Luth_Traditionnel_Ud_Syrie--Nahawand.mp3
# labeling as nahawand
# processing kurd--Riyadh_Al-Sunbati--Maqamat--Taqaseem_Kurd.mp3
# labeling as kurd
# processing segah--Mohammad_Qadri_Dallal--Maqamat_insolites--Maqam_huzam.mp3
# labeling as segah
# processing rast--Farid_Ghosn--Taqasim--Taqsim_Rast.mp3
# labeling as rast
# processing nahawand--Riyadh_Al-Sunbati--Maqamat--Taqaseem_Nahawand.mp3
# labeling as nahawand
# processing hijaz--George_Abyad--Taksims_Oud--Shat_Araban_(8M_33S).mp3
# labeling as hijaz
# processing nahawand--Ali_Jihad_Racy--Simon_Shaheen_‎–_Taqasim__Improvisation_In_Arabic_Music--03_Maqam_Nahawand.mp3
# labeling as nahawand
# processing kurd--Afif_Taian--Various--Sama_i_Hijaz_Kar_kurd--Tatyos_Afendi.mp3
# labeling as kurd
# processing nahawand--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_2--10_Taqsim_Nahawand_(Baida).mp3
# labeling as nahawand
# processing nahawand--Farid_Ghosn--unkonwn_album--Taksim_Nahawand.mp3.mp3
# labeling as nahawand
# [src/libmpg123/id3.c:process_comment():587] error: No comment text / valid description?
# processing hijazkar--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_1--13_Taqsim_Hijaz_Kar_Ala_L-Wahda_(Gramophone).mp3
# labeling as hijazkar
# processing rast--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_2--17_Taqsim_Rasd_(Mechian).mp3
# labeling as rast
# processing segah--Omar_Naqichbendi--Luth_Traditionnel_Ud_Syrie--Sikah-Iraq.mp3
# labeling as segah
# processing rast--Abd_al-Mon_em__Arafa--Various--Taqsim_Rast.mp3
# labeling as rast
# processing hijaz--Farid_Ghosn--unkonwn_album--Taksim_Hijaz.mp3
# labeling as hijaz
# [src/libmpg123/id3.c:process_comment():587] error: No comment text / valid description?
# processing segah--Omar_Naqichbendi--Luth_Traditionnel_Ud_Syrie--Sikah-Huzam.mp3
# labeling as segah
# processing rast--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_1--11_Taqsim_Us_Rasd_(Baida).mp3
# labeling as rast
# processing bayat--Mohammad_al-Qasabji--Various--Taqsim_bayat--1930.mp3
# labeling as bayat
# processing rast--Riyadh_Al-Sunbati--Maqamat--Taqaseem_Rast.mp3
# labeling as rast
# processing rast--George_Abyad--Taksims_Oud--rast--(8M_18S).mp3
# labeling as rast
# processing bayat--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_2--19_Taqsim_Bayyati_(Sodwa).mp3
# labeling as bayat
# processing bayat--Ghassan_Bashir--Taqasim--Bayati.mp3.mp3
# labeling as bayat
# processing rast--Mohammad_al-Qasabji--Various--Oud_Taqsim--1962.mp3
# labeling as rast
# processing rast--Mohammad_al-Qasabji--Taqasim--Taqsim_Rast.mp3
# labeling as rast
# processing segah--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_1--08_Bashraf_Qarbatak_Sikah_(Gramophone_HMV).mp3
# labeling as segah
# processing saba--Mohammad_al-Qasabji--Various--Taqsim_saba--1930.mp3
# labeling as saba
# processing rast--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_1--05_Taqsim_Suznak_(Orfeon).mp3
# labeling as rast
# processing rast--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_2--09_Taqsim_Rasd_(Baida).mp3
# labeling as rast
# processing hijazkar--Munir_Bashir-Art_of_the_Ud-03_Taqsim_en_Maqam__Hijaz_Kar_Kurd.mp3
# labeling as hijazkar
# [src/libmpg123/id3.c:process_comment():587] error: No comment text / valid description?
# processing saba--unknown_artist----Un_Voyage_Avec_Le_Oud_Arabe_1--14_Taqsim_saba--(Odeon).mp3
# labeling as saba
# processing rast--Rawhi_Al-Khammash--unknown_album--Taqsim_Rast.mp3
# labeling as rast
# processing bayat--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_1--18_Taqsim_Bayyati_(Baida).mp3
# labeling as bayat
# processing bayat--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_1--09_Taqsim_Bayyati_(Gramophone).mp3
# labeling as bayat
# processing saba--Ehsan_Emam--Bein_Al-Nahrain--Taqasim_Saba.mp3
# labeling as saba
# processing bayat--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_2--01_Taqsim_Bayyati.mp3
# labeling as bayat
# processing rast--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_2--14_Taqsim_Rasd_(Colombia).mp3
# labeling as rast
# processing segah--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_2--21_Taqsim_Sikah_(Salem_Phone).mp3
# labeling as segah
# processing rast--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_1--16_Taqsim_Rasd_(Fabrik_Mechian).mp3
# labeling as rast
# processing hijaz--George_Abyad--Taksims_Oud--hijaz--(8M_43S).mp3
# labeling as hijaz
# processing saba--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_2--06_Taqsim_Saba_(Baidaphon).mp3
# labeling as saba
# processing hijaz--Farid_Ghosn--Taqasim--hijaz--Taksim-16227.mp3
# labeling as hijaz
# processing nahawand--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_1--21_Samai_nahawand--(Polyphon).mp3
# labeling as nahawand
# processing nahawand--Mohammad_al-Qasabji--Various--Taqsim_nahawand--1926.mp3
# labeling as nahawand
# processing hijaz--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_1--19_Taqsim_Hijaz.mp3
# labeling as hijaz
# processing bayat--Munir_Bashir-Art_of_the_Ud-08_Taqsim_en_Maqam__Dasht.mp3
# labeling as bayat
# [src/libmpg123/id3.c:process_comment():587] error: No comment text / valid description?
# processing rast--Mohammad_al-Qasabji--Various--Samai_rast--v2.mp3
# labeling as rast
# processing hijaz--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_1--17_Taqsim_hijaz--(Baida).mp3
# labeling as hijaz
# processing hijaz--Omar_Naqichbendi--Luth_Traditionnel_Ud_Syrie--Hijaz-Nawa.mp3
# labeling as hijaz
# processing rast--Munir_Bashir-Art_of_the_Ud-02_Taqsim_en_Maqam__Rast.mp3
# labeling as rast
# processing bayat--George_Abyad--Taksims_Oud--Bayati_(7M_39S).mp3
# labeling as bayat
# processing kurd--Mohammad_al-Qasabji--Various--Taqsim_Hijaz_Kar_kurd--1939.mp3
# labeling as kurd
# processing hijaz--Ghassan_Bashir--Taqasim--hijaz--Rast_Bayat.mp3.mp3
# labeling as hijaz
# processing rast--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_1--22_Taqsim_Rasd_(Odeon).mp3
# labeling as rast
# processing nahawand--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_1--20_Taqsim_nahawand--(Polyphon).mp3
# labeling as nahawand
# processing nahawand--Mohammad_al-Qasabji--Taqasim--Taqsim_Nahawand.mp3
# labeling as nahawand
# processing bayat--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_2--20_Taqsim_Bayyati_Al-Nawa_(Alam_Phone).mp3
# labeling as bayat
# processing nahawand--Jamil_Ghanim--Luth_Au_Yemen_Classique_Ud--Reveries_en_Nihawand_en_Fa.mp3
# labeling as nahawand
# processing hijaz--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_1--10_Taqsim-S_hijaz--(Gramophone).mp3
# labeling as hijaz
# processing rast--Jamil_Bashir--unknown_album--Taqsim_Nahawand_rast--Ya_Shadi_l_Alhan.mp3
# labeling as rast
# processing nahawand--Munir_Bashir-Art_of_the_Ud-01_Taqsim_en_Maqam__Nahawand-Kabir.mp3
# labeling as nahawand
# [src/libmpg123/id3.c:process_comment():587] error: No comment text / valid description?
# processing hijaz--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_2--18_Taqsim_Hijaz_(_Sodwa).mp3
# labeling as hijaz
# processing kurd--George_Michele--Various--Taqsim_Hijaz_Kar_Kurd.mp3
# labeling as kurd
# processing bayat--Ehsan_Emam--Bein_Al-Nahrain--Raqs_Al-Mahaba_(Bayat).mp3
# labeling as bayat
# processing bayat--Jamil_Bashir--unknown_album--Taqsim_Bayat.mp3
# labeling as bayat
# processing bayat--Mohammad_al-Qasabji--Taqasim--Taqsim_Bayat.mp3
# labeling as bayat
# processing hijaz--Jamil_Bashir--unknown_album--Song_in_Hijaz.mp3
# labeling as hijaz
# processing hijazkar--Riyadh_Al-Sunbati--Maqamat--Taqaseem_Hijaz_Kar.mp3
# labeling as hijazkar
# processing rast--Mohammad_al-Qasabji--Various--Samai_Rast.mp3
# labeling as rast
# processing rast--Ehsan_Emam--Bein_Al-Nahrain--Taqasim_Rast.mp3
# labeling as rast
# processing hijazkar--Mohammad_al-Qasabji--Various--Taqsim_Hijaz_Kar_1929.mp3
# labeling as hijazkar
# processing segah--Mohammad_Qadri_Dallal--Maqamat_insolites--Maqam_bastah_nikar.mp3
# labeling as segah
# processing hijazkar--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_1--04_Taqsim_Hijaz_Kar_(Odeon).mp3
# labeling as hijazkar
# processing nahawand--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_2--23_Taqsim_Nahawand_Wahda_(Decca).mp3
# labeling as nahawand
# processing hijazkar--Ehsan_Emam--Bein_Al-Nahrain--Taqasim_Hijaz_Kar.mp3
# labeling as hijazkar
# processing bayat--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_1--23_Taqsim_Shadd_Urban_(Odeon).mp3
# labeling as bayat
# processing kurd--Munir_Bashir-Art_of_the_Ud-06_Taqsim_en_Maqam__Kurdi.mp3
# labeling as kurd
# [src/libmpg123/id3.c:process_comment():587] error: No comment text / valid description?
# processing bayat--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_2--07_Taqsim_Bayyati_(Baidaphon).mp3
# labeling as bayat
# processing segah--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_2--05_Taqsim_Muhayyar_Iraq_(Baidaphon).mp3
# labeling as segah
# processing rast--Omar_Naqichbendi--Luth_Traditionnel_Ud_Syrie--Rast.mp3
# labeling as rast
# processing nahawand--Jamil_Bashir--unknown_album--Sama_i_nahawand--Mas_ud_Jamil_Bek.mp3
# labeling as nahawand
# processing rast--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_1--03_Taqsim_Rasd_(Odeon).mp3
# labeling as rast
# processing bayat--Ali_Jihad_Racy--Simon_Shaheen_‎–_Taqasim__Improvisation_In_Arabic_Music--02_Maqam_Bayati.mp3
# labeling as bayat
# processing rast--Jamil_Bashir--unknown_album--Sama_i_Rast.mp3
# labeling as rast
# processing saba--Omar_Naqichbendi--Luth_Traditionnel_Ud_Syrie--Saba-Husayni.mp3
# labeling as saba
# processing hijazkar--unknown_artist--Un_Voyage_Avec_Le_Oud_Arabe_2--08_Taqsim_Hijaz_Kar_Kurd.mp3
# labeling as hijazkar
# processing kurd--Jamil_Bashir--unknown_album--Longa_Hijaz_Kar_kurd--Sboukh_Afendi.mp3
# labeling as kurd
# processing bayat--Riyadh_Al-Sunbati--Maqamat--Taqaseem_Bayati.mp3
# labeling as bayat
# processing nahawand--Ehsan_Emam--Bein_Al-Nahrain--Bein_Al-Nahrain_(Nahawand).mp3
# labeling as nahawand
# 104

# %%
mel
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 mel
#
# NameError: name 'mel' is not defined
